# %% [markdown]
# # Load DataFrames

# %%
import pandas as pd

# %%
filename = "../ZZ_Data/cars.csv"
df = pd.read_csv(filename)
df = pd.read_csv(filename)
df.head(3)
df.tail(3)
# Out:
#               Name  Miles_per_Gallon  Cylinders  Displacement  Horsepower  \
# 403  dodge rampage              32.0          4         135.0        84.0
# 404    ford ranger              28.0          4         120.0        79.0
# 405     chevy s-10              31.0          4         119.0        82.0
#
#      Weight_in_lbs  Acceleration        Year Origin
# 403           2295          11.6  1982-01-01    USA
# 404           2625          18.6  1982-01-01    USA
# 405           2720          19.4  1982-01-01    USA

# %% [markdown]
# ## Limit number of data read from file

# %%
filename = "NeutralData/cars.csv"
colsIwannaUse = ["Name", "Cylinders"]
df = pd.read_csv(filename, usecols = colsIwannaUse, nrows = 3)
df
# Out:
#                         Name  Cylinders
# 0  chevrolet chevelle malibu          8
# 1          buick skylark 320          8
# 2         plymouth satellite          8

# %% [markdown]
# ## Delimiter comma and header in top row can, but need not be specified

# %%
df = pd.read_csv(filename, delimiter = ",", header=0)
df.head(3)
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
#
#    Horsepower  Weight_in_lbs  Acceleration        Year Origin
# 0       130.0           3504          12.0  1970-01-01    USA
# 1       165.0           3693          11.5  1970-01-01    USA
# 2       150.0           3436          11.0  1970-01-01    USA

# %% [markdown]
# ## Converter

# %%
df = pd.read_csv(filename, converters={"Cylinders": int()})
df.Cylinders = df.Cylinders + 7
df.head(3)
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0         15         307.0
# 1          buick skylark 320              15.0         15         350.0
# 2         plymouth satellite              18.0         15         318.0
#
#    Horsepower  Weight_in_lbs  Acceleration        Year Origin
# 0       130.0           3504          12.0  1970-01-01    USA
# 1       165.0           3693          11.5  1970-01-01    USA
# 2       150.0           3436          11.0  1970-01-01    USA

# %%
def square(x):
    x = int(x)
    return x*x
def extract(x):
    return x[0:2]
#return 3*int(x)
df = pd.read_csv(filename, converters={"Cylinders": square, "Horsepower": extract})
df.head(3)
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0         64         307.0
# 1          buick skylark 320              15.0         64         350.0
# 2         plymouth satellite              18.0         64         318.0
#
#   Horsepower  Weight_in_lbs  Acceleration        Year Origin
# 0         13           3504          12.0  1970-01-01    USA
# 1         16           3693          11.5  1970-01-01    USA
# 2         15           3436          11.0  1970-01-01    USA

# %% [markdown]
# ## Missing Values

# %%
df = pd.read_csv(filename, na_values = [4],  na_filter=True)
df = df.fillna(777)
df.head(13)
# Out:
#                                 Name  Miles_per_Gallon  Cylinders  \
# 0          chevrolet chevelle malibu              18.0        8.0
# 1                  buick skylark 320              15.0        8.0
# 2                 plymouth satellite              18.0        8.0
# 3                      amc rebel sst              16.0        8.0
# 4                        ford torino              17.0        8.0
# 5                   ford galaxie 500              15.0        8.0
# 6                   chevrolet impala              14.0        8.0
# 7                  plymouth fury iii              14.0        8.0
# 8                   pontiac catalina              14.0        8.0
# 9                 amc ambassador dpl              15.0        8.0
# 10              citroen ds-21 pallas             777.0      777.0
# 11  chevrolet chevelle concours (sw)             777.0        8.0
# 12                  ford torino (sw)             777.0        8.0
#
# ...

# %% [markdown]
# ## Dates

# %% [markdown]
# when reading, parse_dates=['column name']  is usually enough to magically parse into a date format

# %%
filename = "NeutralData/co2.csv"
df = pd.read_csv(filename, parse_dates=["Date"])
from datetime import timedelta, date
df["DatePlus"]= df.Date + timedelta(days=180)
df.head(10)
# Out:
#         Date     CO2  adjusted CO2   DatePlus
# 0 1958-03-01  315.70        314.44 1958-08-28
# 1 1958-04-01  317.46        315.16 1958-09-28
# 2 1958-05-01  317.51        314.71 1958-10-28
# 3 1958-07-01  315.86        315.19 1958-12-28
# 4 1958-08-01  314.93        316.19 1959-01-28
# 5 1958-09-01  313.21        316.08 1959-02-28
# 6 1958-11-01  313.33        315.20 1959-04-30
# 7 1958-12-01  314.67        315.43 1959-05-30
# 8 1959-01-01  315.58        315.54 1959-06-30
# 9 1959-02-01  316.49        315.86 1959-07-31

# %% [markdown]
# ## Transposed Data

# %%
filename = "NeutralData/Covid_Data.csv"
df = pd.read_csv(filename, parse_dates=["Province/State"], header=0).T
df
# Out:
#                         0        1        2        3        4    \
# Province/State          NaN      NaN      NaN      NaN      NaN
# Country/Region  Afghanistan  Albania  Algeria  Andorra   Angola
# Lat                33.93911  41.1533  28.0339  42.5063 -11.2027
# Long              67.709953  20.1683   1.6596   1.5218  17.8739
# 1/22/20                   0        0        0        0        0
# ...                     ...      ...      ...      ...      ...
# 2/15/21               55514    93850   110894    10538    20381
# 2/16/21               55518    94651   111069    10555    20389
# 2/17/21               55540    95726   111247    10583    20400
# 2/18/21               55557    96838   111418    10610    20452
# 2/19/21               55575    97909   111600    10645    20478
#
#                                 5          6        7    \
# Province/State                  NaN        NaN      NaN
# Country/Region  Antigua and Barbuda  Argentina  Armenia
# ...

# %%
df.to_csv('mySavedDF.csv', index=False, sep=";", encoding="utf-8")

# %% [markdown]
# # Visualization with Pandas, Matplotlib and Seaborn

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename = "../ZZ_Data/cars.csv"
df = pd.read_csv(filename)
colsIwannaUse = ["Horsepower", "Acceleration"]
df = pd.read_csv(filename, usecols = colsIwannaUse, nrows = 500)
df.head(3)
df.tail(3)
# Out:
#      Horsepower  Acceleration
# 403        84.0          11.6
# 404        79.0          18.6
# 405        82.0          19.4

# %% [markdown]
# ## Create the figure

# %%
### Creage both a figure and an 'axis' (which is a graph within the figure)
fig, ax = plt.subplots(figsize=(8, 5))

# %%
### Colors and spacings
fig.set_facecolor('xkcd:cloudy blue')
ax.set_facecolor('xkcd:pale grey')
plt.subplots_adjust(left=0.12, right=0.91, top=0.82, bottom=0.15)
ax.xaxis.grid(linestyle="--", linewidth=0.5)
ax.yaxis.grid(linestyle="--", linewidth=0.5)
fig

# %%
### Set title and configure axis
myColor1 = "#605f82"
ax.set_title("Good Acceleration?", fontsize=24, fontweight=800, pad = 18, color=myColor1, fontfamily="Ubuntu")
ax.set_xlabel(xlabel = df.columns.values[0], fontsize=16, color=myColor1, labelpad = 8)
ax.set_ylabel(ylabel = df.columns.values[1], fontsize=18, color=myColor1, labelpad = 8)
fig

# %%
### Range of x/y-axis
ax.set_xticks(np.arange(-0, 251, 50))
ax.set_yticks(np.arange(0, 31, 5))
fig

# %%
### Beautifications
ax.tick_params(axis='x', colors=myColor1, rotation=90)
ax.tick_params(axis='y', colors=myColor1)

ax.spines['bottom'].set_color(myColor1)
ax.spines['left'].set_color(myColor1)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
fig

# %%
### Configure marker color, size and shape
g = sns.scatterplot(ax = ax, x="Horsepower", y="Acceleration", data=df, color=myColor1, marker="s", s=30)
g.figure
